# %%
########################################################################################################
#Name : - hiral shingadiya 
#Enrollment :- 216270307061
#Subject :- IML
#Sem :- 5
########################################################################################################

#Practical - 2 : Write a NumPy program to implement following operation

#Practical - 2.1 to convert a list of numeric values into a one-dimensional NumPy array

import numpy as np

a = [12,14,22,23,19]
print("List is : ",a)

b = np.array(a)
print("Array is : ",a)

# %%
########################################################################################################
#Name : - hiral shingadiya 
#Enrollment :- 216270307061
#Subject :- IML
#Sem :- 5
########################################################################################################

#Practical - 2.2 to create a 3x3 matrix with values ranging from 2 to 10

import numpy as np

a = [[2,3,4],[5,6,7],[8,9,10]]
for i in a:
    print(i)

# %%
########################################################################################################
#Name : - hiral shingadiya
#Enrollment :- 216270307061
#Subject :- IML
#Sem :- 5
########################################################################################################

#Practical - 2.3 to append values at the end of an array

from numpy import random

x = random.randint(50)
arr = [7,8,9]
print("Array : ",arr)
print("Array after appending digit : ",arr.append(x))

# %%
########################################################################################################
#Name : - hiral shingadiya
#Enrollment :- 216270307061
#Subject :- IML
#Sem :- 5
########################################################################################################

#Practical - 2.4 to create another shape from an array without changing its data(3*2 to 2*3) 

import numpy as np

arr = [1,2,3,4,5,6]
print("Array : ",arr,"\n")
arr1 = np.reshape(arr,(3,2))
print("Array 3x2 : \n",arr1)
arr2 = np.reshape(arr,(2,3))
print("\nArray 2x3 : \n",arr2)
